# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import numpy as np
from data import clean_data, rule_filter, make_useful_data
from sklearn.preprocessing import LabelEncoder
# Out:
# /home/stein/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data1 = pd.read_csv("final_csv/final_first_mapped_reaction.csv")
data2 = pd.read_csv("final_csv/final_second_mapped_reaction.csv")
data3 = pd.read_csv("final_csv/final_third_mapped_reaction.csv")
data4 = pd.read_csv("final_csv/final_fourth_mapped_reaction.csv")

# %%
data = pd.concat([data1, data2, data3, data4], axis=0)

# %%
make_useful_data(data, save_path="new_useful_data")
# Out:
# coverage_rate 0.7596822068804934
# coverage_rate 0.5127329823665983
# /home/stein/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/stein/PycharmProjects/Retrosynthetic/exp_rot_nets/data.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data_expand_network["y"] = lbl_exp.fit_transform(oexpand_rule_labels)
# ...

# %%
dexp = pd.read_csv("useful_data/data_expand_network.csv")
drot = pd.read_csv("useful_data/data_rollout_network.csv")

# %%
lexp = LabelEncoder()
lrot = LabelEncoder()

# %%
lexp.classes_ = np.load("useful_data/expand_rule_label_encoder.npy")
lrot.classes_ = np.load("useful_data/rollout_rule_label_encoder.npy")

# %%
dexp
# Out:
#                                     mapped_reaction_smiles  \
# 0        [CH3:1][N:2]([CH3:3])[CH2:4][CH2:5][OH:6].[Cl:...
# 1        [OH:1][CH:2]1[CH2:3][N:4]([CH2:5]1)[C:6](=[O:7...
# 2        [H:1][C@@:2]12[CH2:3][CH2:4][C@H:5]([CH2:6][C@...
# 3        [CH3:1][CH:2]([CH3:3])[CH:4]1[CH2:5][CH2:6][C:...
# 4        [CH3:1][CH2:2][CH2:3][N:4]=[C:5]=[S:6].[CH3:7]...
# 5        [CH3:1][O:2][C:3](=[O:4])\[CH:5]=[CH:6]\[CH2:7...
# 6        [Br:1][c:2]1[c:3][c:4][c:5](\\[#6:6]=[#6:7]-2/...
# 7        [CH2:1]=[N:2]#[N:3].[CH3:4][CH:5]([CH3:6])[C:7...
# 8        [CH3:1][CH:2]([CH3:3])[C:4]([N:5]=[C:6]=[O:7])...
# 9        [CH3:1][N:2]([CH3:3])[CH2:4][CH2:5][OH:6]>>[CH...
# 10       [CH3:1][O:2][C:3](=[O:4])[C@H:5]([NH:6][C:7](=...
# 11       [H:1][C@@:2]12[CH2:3][C@:4]1([H:5])[N:6]([C@@H...
# 12       [cH:1]1[n:2][c:3]2[cH:4][cH:5][cH:6][cH:7][c:8...
# 13       [H:1][C@@:2]([CH3:3])([CH2:4][CH2:5][CH2:6][CH...
# 14       [CH3:1][c:2]1[cH:20][c:18]([CH3:19])[cH:17][c:...
# ...

# %%
lexp.inverse_transform(dexp.y.values)[:10]
# Out:
# /home/stein/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array(['[O&H1:2].[Cl&H1:4].[Cl:3]-,:[C:1]>>[O:2]-,:[C:1]',
#        '[N&H1:1].[C&H1:2]=[O:3]>>[N:1]-,:[C&H2:2]',
#        '[C&H1:1]-,:[O&H1:2]>>[C:1]=[O:2]',
#        '[C&H1:1]=[O:2]>>[C&H1:1]=[N:3]-,:[O&H1:2]',
#        '[N:1]=[C:2].[C&H1:3]=[O:8].[Cl&H1:6].[O:7]-,:[C:4].[N&H2:5]>>[N:1](-,:[C:2]-,:[N:5]-,:[C&H2:3])-,:[C:4]',
#        '[C&H1:1]=[C&H1:3].[#3&H1:4].[N&H1:2]>>[C&H2:1]-,:[C&H1:3]-,:[N:2]',
#        '[C&H1:2]=[C:3]-,:[C&H2:1]>>[C&H2:2]-,:[C:3]=[C&H1:1]',
#        '[C&H2:1].[C:2]-,:[O&H1:3]>>[C&H1:1]-,:[C:2]',
#        '[N:1]=[C:2]>>[N&H2:1]', '[O&H1:1]>>[O:1]-,:[C:2]'], dtype=object)
